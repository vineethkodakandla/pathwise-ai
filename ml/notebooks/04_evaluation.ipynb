# %% [markdown]
# # 04 - Model Evaluation
#
# Evaluate the trained LSTM model against PVD requirements.
#
# ## Metrics
# 1. MSE per metric (latency, jitter, packet_loss)
# 2. MAE per metric
# 3. Brownout detection recall (>=90% target)
# 4. False positive rate (<10% target)
# 5. Prediction horizon accuracy analysis

# %%
import sys
sys.path.insert(0, '../../')

from ml.scripts.evaluate import evaluate_model, compute_health_from_preds
print('Evaluation module loaded successfully')
