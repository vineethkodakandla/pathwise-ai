# %% [markdown]
# # 01 - Data Exploration
#
# Explore raw and synthetic telemetry data for PathWise AI.
#
# ## Goals
# - Load synthetic telemetry data
# - Visualize diurnal patterns, brownout events
# - Compute basic statistics per link
# - Identify correlations between metrics

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load synthetic data
df = pd.read_parquet('../data/synthetic/fiber-primary.parquet')
print(f'Shape: {df.shape}')
df.head()
